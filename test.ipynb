# %%
from camera import Camera

# %%
camera = Camera()

# %%
camera.connect()
# Out:
# True

# %%
camera.all_device()
# Out:
# [{'name': 'Intel RealSense D405',
#   'serial_number': '315122271350',
#   'obj': <pyrealsense2.device: Intel RealSense D405 (S/N: 315122271350  FW: 05.12.14.100  on USB3.2)>}]

# %%
import pyrealsense2 as rs

ctx = rs.context()

# Get a list of all connected devices
devices = ctx.query_devices()

# %%
d = devices[0]

# %%
d.get_info(rs.camera_info.physical_port)
# Out:
# '\\\\?\\usb#vid_8086&pid_0b5b&mi_00#9&325db261&0&0000#{e5323777-f976-4f5b-9b55-b94699c46e44}\\global'

# %%
d.get_info(rs.camera_info.physical_port)
# Out:
# '\\\\?\\usb#vid_8086&pid_0b5b&mi_00#9&325db261&0&0000#{e5323777-f976-4f5b-9b55-b94699c46e44}\\global'
